# %%
import sqlite3
import yfinance as yf
import pandas as pd
import numpy as np
from time import sleep
from requests.exceptions import SSLError
from datetime import date

# %%
conn = sqlite3.connect('sp500_stocks.db')
cursor = conn.cursor()

# %% [markdown]
# # Sectors, industry and sub-industry

# %%
mapping = pd.read_csv('gics_mapping.csv')
mapping = mapping.applymap(lambda x: x.strip() if type(x) == str else x)
mapping.head()
# Out:
#    sector_id  sector  industry_id                     industry  \
# 0          1  Energy          101  Energy Equipment & Services
# 1          1  Energy          101  Energy Equipment & Services
# 2          1  Energy          102  Oil, Gas & Consumable Fuels
# 3          1  Energy          102  Oil, Gas & Consumable Fuels
# 4          1  Energy          102  Oil, Gas & Consumable Fuels
#
#    sub_industry_id                        sub_industry
# 0            10101                  Oil & Gas Drilling
# 1            10102      Oil & Gas Equipment & Services
# 2            10201                Integrated Oil & Gas
# 3            10202  Oil & Gas Exploration & Production
# 4            10203      Oil & Gas Refining & Marketing

# %%
#Populate sectors
sector_data = mapping[['sector_id', 'sector']].drop_duplicates()
sector_insert_data = []
for i in range(0, sector_data.shape[0]):
    # Ensure sector_id is int and sector is str
    sector_insert_data.append((int(sector_data['sector_id'].iloc[i]), str(sector_data['sector'].iloc[i])))
insert_sectors = """
INSERT OR IGNORE INTO sectors (sector_id, sector) 
VALUES (?, ?)"""

cursor.executemany(insert_sectors, sector_insert_data)

# %%
# Populate industries
industry_data = mapping[['sector_id', 'industry_id', 'industry']].drop_duplicates()
industry_insert_data = []
for i in range(0, industry_data.shape[0]):
    industry_insert_data.append((int(industry_data['sector_id'].iloc[i]), int(industry_data['industry_id'].iloc[i]), str(industry_data['industry'].iloc[i])))
insert_industry = """
INSERT OR IGNORE INTO industries (sector_id, industry_id, industry) 
VALUES (?, ?, ?)"""
cursor.executemany(insert_industry, industry_insert_data)

# %%
# Populate sub-industries
sub_industry_data = mapping[['sector_id', 'industry_id', 'sub_industry_id', 'sub_industry']].drop_duplicates()
sub_industry_insert_data = []
for i in range(0, sub_industry_data.shape[0]):
    sub_industry_insert_data.append((int(sub_industry_data['sector_id'].iloc[i]), int(sub_industry_data['industry_id'].iloc[i]), int(sub_industry_data['sub_industry_id'].iloc[i]), str(sub_industry_data['sub_industry'].iloc[i])))
insert_sub_industry = """
INSERT OR IGNORE INTO sub_industries (sector_id, industry_id, sub_industry_id, sub_industry) 
VALUES (?, ?, ?, ?)"""
cursor.executemany(insert_sub_industry, sub_industry_insert_data)

# %%
cursor.execute("SELECT * FROM sectors")
sectors = cursor.fetchall() 
sectors_df = pd.DataFrame(sectors, columns=['sector_id', 'sector'])
sectors_df
# Out:
#     sector_id                  sector
# 0           1                  Energy
# 1           2               Materials
# 2           3             Industrials
# 3           4               Utilities
# 4           5             Health Care
# 5           6              Financials
# 6           7  Consumer Discretionary
# 7           8        Consumer Staples
# 8           9  Information Technology
# 9          10  Communication Services
# 10         11             Real Estate

# %%
cursor.execute("SELECT * FROM industries")
industries = cursor.fetchall()
industries_df = pd.DataFrame(industries, columns=['industry_id', 'sector_id', 'industry'])
industries_df
# Out:
#     industry_id  sector_id                              industry
# 0             1        101           Energy Equipment & Services
# 1             1        102           Oil, Gas & Consumable Fuels
# 2             2        201                             Chemicals
# 3             2        202                Construction Materials
# 4             2        203                Containers & Packaging
# ..          ...        ...                                   ...
# 68           11       1105                     Health Care REITs
# 69           11       1106                     Residential REITs
# 70           11       1107                          Retail REITs
# 71           11       1108                     Specialized REITs
# 72           11       1109  Real Estate Management & Development
#
# [73 rows x 3 columns]

# %%
cursor.execute("SELECT * FROM sub_industries")
sub_industries = cursor.fetchall()
sub_industries_df = pd.DataFrame(sub_industries, columns=['sub_industry_id', 'sector_id', 'industry_id', 'sub_industry'])
sub_industries_df
# Out:
#      sub_industry_id  sector_id  industry_id  \
# 0                  1        101        10101
# 1                  1        101        10102
# 2                  1        102        10201
# 3                  1        102        10202
# 4                  1        102        10203
# ..               ...        ...          ...
# 158               11       1108       110805
# 159               11       1109       110901
# 160               11       1109       110902
# 161               11       1109       110903
# 162               11       1109       110904
#
#                            sub_industry
# 0                    Oil & Gas Drilling
# 1        Oil & Gas Equipment & Services
# 2                  Integrated Oil & Gas
# 3    Oil & Gas Exploration & Production
# 4        Oil & Gas Refining & Marketing
# ..                                  ...
# 158                   Data Center REITs
# 159  Diversified Real Estate Activities
# 160     Real Estate Operating Companies
# 161             Real Estate Development
# 162                Real Estate Services
#
# [163 rows x 4 columns]

# %% [markdown]
# # Stock Information

# %%
sp_comp_tickers = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['Symbol'].to_list()
sp_comp_sectors = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['GICS Sector'].to_list()
sp_comp_sub_industries = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['GICS Sub-Industry'].to_list()

# %%
sp_comp_data = []
for ticker,sector, sub_ind in zip(sp_comp_tickers,sp_comp_sectors, sp_comp_sub_industries):
    ticker = ticker.replace('.', '-')  # Replace '.' with '-' for yfinance compatibility
    print(f"Fetching data for {ticker}...")
    stock = yf.Ticker(ticker).info
    sp_comp_data.append((stock['symbol'], stock['shortName'], sector, sub_ind, stock['marketCap'], stock['longBusinessSummary']))
# Out:
# Fetching data for MMM...
# Fetching data for AOS...
# Fetching data for ABT...
# Fetching data for ABBV...
# Fetching data for ACN...
# Fetching data for ADBE...
# Fetching data for AMD...
# Fetching data for AES...
# Fetching data for AFL...
# Fetching data for A...
# Fetching data for APD...
# Fetching data for ABNB...
# Fetching data for AKAM...
# Fetching data for ALB...
# Fetching data for ARE...
# Fetching data for ALGN...
# Fetching data for ALLE...
# Fetching data for LNT...
# Fetching data for ALL...
# Fetching data for GOOGL...
# Fetching data for GOOG...
# Fetching data for MO...
# Fetching data for AMZN...
# Fetching data for AMCR...
# Fetching data for AEE...
# Fetching data for AEP...
# Fetching data for AXP...
# Fetching data for AIG...
# Fetching data for AMT...
# Fetching data for AWK...
# Fetching data for AMP...
# Fetching data for AME...
# Fetching data for AMGN...
# Fetching data for APH...
# Fetching data for ADI...
# Fetching data for AON...
# Fetching data for APA...
# Fetching data for APO...
# Fetching data for AAPL...
# Fetching data for AMAT...
# Fetching data for APTV...
# Fetching data for ACGL...
# Fetching data for ADM...
# Fetching data for ANET...
# Fetching data for AJG...
# Fetching data for AIZ...
# Fetching data for T...
# Fetching data for ATO...
# Fetching data for ADSK...
# Fetching data for ADP...
# Fetching data for AZO...
# Fetching data for AVB...
# Fetching data for AVY...
# Fetching data for AXON...
# Fetching data for BKR...
# Fetching data for BALL...
# Fetching data for BAC...
# Fetching data for BAX...
# Fetching data for BDX...
# Fetching data for BRK-B...
# Fetching data for BBY...
# Fetching data for TECH...
# Fetching data for BIIB...
# Fetching data for BLK...
# Fetching data for BX...
# Fetching data for XYZ...
# Fetching data for BK...
# Fetching data for BA...
# Fetching data for BKNG...
# Fetching data for BSX...
# Fetching data for BMY...
# Fetching data for AVGO...
# Fetching data for BR...
# Fetching data for BRO...
# Fetching data for BF-B...
# Fetching data for BLDR...
# Fetching data for BG...
# Fetching data for BXP...
# Fetching data for CHRW...
# Fetching data for CDNS...
# Fetching data for CZR...
# Fetching data for CPT...
# Fetching data for CPB...
# Fetching data for COF...
# Fetching data for CAH...
# Fetching data for KMX...
# Fetching data for CCL...
# Fetching data for CARR...
# Fetching data for CAT...
# Fetching data for CBOE...
# Fetching data for CBRE...
# Fetching data for CDW...
# Fetching data for COR...
# Fetching data for CNC...
# Fetching data for CNP...
# Fetching data for CF...
# Fetching data for CRL...
# Fetching data for SCHW...
# Fetching data for CHTR...
# Fetching data for CVX...
# Fetching data for CMG...
# Fetching data for CB...
# Fetching data for CHD...
# Fetching data for CI...
# Fetching data for CINF...
# Fetching data for CTAS...
# Fetching data for CSCO...
# Fetching data for C...
# Fetching data for CFG...
# Fetching data for CLX...
# Fetching data for CME...
# Fetching data for CMS...
# Fetching data for KO...
# Fetching data for CTSH...
# Fetching data for COIN...
# Fetching data for CL...
# Fetching data for CMCSA...
# Fetching data for CAG...
# Fetching data for COP...
# Fetching data for ED...
# Fetching data for STZ...
# Fetching data for CEG...
# Fetching data for COO...
# Fetching data for CPRT...
# Fetching data for GLW...
# Fetching data for CPAY...
# Fetching data for CTVA...
# Fetching data for CSGP...
# Fetching data for COST...
# Fetching data for CTRA...
# Fetching data for CRWD...
# Fetching data for CCI...
# Fetching data for CSX...
# Fetching data for CMI...
# Fetching data for CVS...
# Fetching data for DHR...
# Fetching data for DRI...
# Fetching data for DDOG...
# Fetching data for DVA...
# Fetching data for DAY...
# Fetching data for DECK...
# Fetching data for DE...
# Fetching data for DELL...
# Fetching data for DAL...
# Fetching data for DVN...
# Fetching data for DXCM...
# Fetching data for FANG...
# Fetching data for DLR...
# Fetching data for DG...
# Fetching data for DLTR...
# Fetching data for D...
# Fetching data for DPZ...
# Fetching data for DASH...
# Fetching data for DOV...
# Fetching data for DOW...
# Fetching data for DHI...
# Fetching data for DTE...
# Fetching data for DUK...
# Fetching data for DD...
# Fetching data for EMN...
# Fetching data for ETN...
# Fetching data for EBAY...
# Fetching data for ECL...
# Fetching data for EIX...
# Fetching data for EW...
# Fetching data for EA...
# Fetching data for ELV...
# Fetching data for EMR...
# Fetching data for ENPH...
# Fetching data for ETR...
# Fetching data for EOG...
# Fetching data for EPAM...
# Fetching data for EQT...
# Fetching data for EFX...
# Fetching data for EQIX...
# Fetching data for EQR...
# Fetching data for ERIE...
# Fetching data for ESS...
# Fetching data for EL...
# Fetching data for EG...
# Fetching data for EVRG...
# Fetching data for ES...
# Fetching data for EXC...
# Fetching data for EXE...
# Fetching data for EXPE...
# Fetching data for EXPD...
# Fetching data for EXR...
# Fetching data for XOM...
# Fetching data for FFIV...
# Fetching data for FDS...
# Fetching data for FICO...
# Fetching data for FAST...
# Fetching data for FRT...
# Fetching data for FDX...
# Fetching data for FIS...
# Fetching data for FITB...
# Fetching data for FSLR...
# Fetching data for FE...
# Fetching data for FI...
# Fetching data for F...
# Fetching data for FTNT...
# Fetching data for FTV...
# Fetching data for FOXA...
# Fetching data for FOX...
# Fetching data for BEN...
# Fetching data for FCX...
# Fetching data for GRMN...
# Fetching data for IT...
# Fetching data for GE...
# Fetching data for GEHC...
# Fetching data for GEV...
# Fetching data for GEN...
# Fetching data for GNRC...
# Fetching data for GD...
# Fetching data for GIS...
# Fetching data for GM...
# Fetching data for GPC...
# Fetching data for GILD...
# Fetching data for GPN...
# Fetching data for GL...
# Fetching data for GDDY...
# Fetching data for GS...
# Fetching data for HAL...
# Fetching data for HIG...
# Fetching data for HAS...
# Fetching data for HCA...
# Fetching data for DOC...
# Fetching data for HSIC...
# Fetching data for HSY...
# Fetching data for HPE...
# Fetching data for HLT...
# Fetching data for HOLX...
# Fetching data for HD...
# Fetching data for HON...
# Fetching data for HRL...
# Fetching data for HST...
# Fetching data for HWM...
# Fetching data for HPQ...
# Fetching data for HUBB...
# Fetching data for HUM...
# Fetching data for HBAN...
# Fetching data for HII...
# Fetching data for IBM...
# Fetching data for IEX...
# Fetching data for IDXX...
# Fetching data for ITW...
# Fetching data for INCY...
# Fetching data for IR...
# Fetching data for PODD...
# Fetching data for INTC...
# Fetching data for ICE...
# Fetching data for IFF...
# Fetching data for IP...
# Fetching data for IPG...
# Fetching data for INTU...
# Fetching data for ISRG...
# Fetching data for IVZ...
# Fetching data for INVH...
# Fetching data for IQV...
# Fetching data for IRM...
# Fetching data for JBHT...
# Fetching data for JBL...
# Fetching data for JKHY...
# Fetching data for J...
# Fetching data for JNJ...
# Fetching data for JCI...
# Fetching data for JPM...
# Fetching data for K...
# Fetching data for KVUE...
# Fetching data for KDP...
# Fetching data for KEY...
# Fetching data for KEYS...
# Fetching data for KMB...
# Fetching data for KIM...
# Fetching data for KMI...
# Fetching data for KKR...
# Fetching data for KLAC...
# Fetching data for KHC...
# Fetching data for KR...
# Fetching data for LHX...
# Fetching data for LH...
# Fetching data for LRCX...
# Fetching data for LW...
# Fetching data for LVS...
# Fetching data for LDOS...
# Fetching data for LEN...
# Fetching data for LII...
# Fetching data for LLY...
# Fetching data for LIN...
# Fetching data for LYV...
# Fetching data for LKQ...
# Fetching data for LMT...
# Fetching data for L...
# Fetching data for LOW...
# Fetching data for LULU...
# Fetching data for LYB...
# Fetching data for MTB...
# Fetching data for MPC...
# Fetching data for MKTX...
# Fetching data for MAR...
# Fetching data for MMC...
# Fetching data for MLM...
# Fetching data for MAS...
# Fetching data for MA...
# Fetching data for MTCH...
# Fetching data for MKC...
# Fetching data for MCD...
# Fetching data for MCK...
# Fetching data for MDT...
# Fetching data for MRK...
# Fetching data for META...
# Fetching data for MET...
# Fetching data for MTD...
# Fetching data for MGM...
# Fetching data for MCHP...
# Fetching data for MU...
# Fetching data for MSFT...
# Fetching data for MAA...
# Fetching data for MRNA...
# Fetching data for MHK...
# Fetching data for MOH...
# Fetching data for TAP...
# Fetching data for MDLZ...
# Fetching data for MPWR...
# Fetching data for MNST...
# Fetching data for MCO...
# Fetching data for MS...
# Fetching data for MOS...
# Fetching data for MSI...
# Fetching data for MSCI...
# Fetching data for NDAQ...
# Fetching data for NTAP...
# Fetching data for NFLX...
# Fetching data for NEM...
# Fetching data for NWSA...
# Fetching data for NWS...
# Fetching data for NEE...
# Fetching data for NKE...
# Fetching data for NI...
# Fetching data for NDSN...
# Fetching data for NSC...
# Fetching data for NTRS...
# Fetching data for NOC...
# Fetching data for NCLH...
# Fetching data for NRG...
# Fetching data for NUE...
# Fetching data for NVDA...
# Fetching data for NVR...
# Fetching data for NXPI...
# Fetching data for ORLY...
# Fetching data for OXY...
# Fetching data for ODFL...
# Fetching data for OMC...
# Fetching data for ON...
# Fetching data for OKE...
# Fetching data for ORCL...
# Fetching data for OTIS...
# Fetching data for PCAR...
# Fetching data for PKG...
# Fetching data for PLTR...
# Fetching data for PANW...
# Fetching data for PARA...
# Fetching data for PH...
# Fetching data for PAYX...
# Fetching data for PAYC...
# Fetching data for PYPL...
# Fetching data for PNR...
# Fetching data for PEP...
# Fetching data for PFE...
# Fetching data for PCG...
# Fetching data for PM...
# Fetching data for PSX...
# Fetching data for PNW...
# Fetching data for PNC...
# Fetching data for POOL...
# Fetching data for PPG...
# Fetching data for PPL...
# Fetching data for PFG...
# Fetching data for PG...
# Fetching data for PGR...
# Fetching data for PLD...
# Fetching data for PRU...
# Fetching data for PEG...
# Fetching data for PTC...
# Fetching data for PSA...
# Fetching data for PHM...
# Fetching data for PWR...
# Fetching data for QCOM...
# Fetching data for DGX...
# Fetching data for RL...
# Fetching data for RJF...
# Fetching data for RTX...
# Fetching data for O...
# Fetching data for REG...
# Fetching data for REGN...
# Fetching data for RF...
# Fetching data for RSG...
# Fetching data for RMD...
# Fetching data for RVTY...
# Fetching data for ROK...
# Fetching data for ROL...
# Fetching data for ROP...
# Fetching data for ROST...
# Fetching data for RCL...
# Fetching data for SPGI...
# Fetching data for CRM...
# Fetching data for SBAC...
# Fetching data for SLB...
# Fetching data for STX...
# Fetching data for SRE...
# Fetching data for NOW...
# Fetching data for SHW...
# Fetching data for SPG...
# Fetching data for SWKS...
# Fetching data for SJM...
# Fetching data for SW...
# Fetching data for SNA...
# Fetching data for SOLV...
# Fetching data for SO...
# Fetching data for LUV...
# Fetching data for SWK...
# Fetching data for SBUX...
# Fetching data for STT...
# Fetching data for STLD...
# Fetching data for STE...
# Fetching data for SYK...
# Fetching data for SMCI...
# Fetching data for SYF...
# Fetching data for SNPS...
# Fetching data for SYY...
# Fetching data for TMUS...
# Fetching data for TROW...
# Fetching data for TTWO...
# Fetching data for TPR...
# Fetching data for TRGP...
# Fetching data for TGT...
# Fetching data for TEL...
# Fetching data for TDY...
# Fetching data for TER...
# Fetching data for TSLA...
# Fetching data for TXN...
# Fetching data for TPL...
# Fetching data for TXT...
# Fetching data for TMO...
# Fetching data for TJX...
# Fetching data for TKO...
# Fetching data for TTD...
# Fetching data for TSCO...
# Fetching data for TT...
# Fetching data for TDG...
# Fetching data for TRV...
# Fetching data for TRMB...
# Fetching data for TFC...
# Fetching data for TYL...
# Fetching data for TSN...
# Fetching data for USB...
# Fetching data for UBER...
# Fetching data for UDR...
# Fetching data for ULTA...
# Fetching data for UNP...
# Fetching data for UAL...
# Fetching data for UPS...
# Fetching data for URI...
# Fetching data for UNH...
# Fetching data for UHS...
# Fetching data for VLO...
# Fetching data for VTR...
# Fetching data for VLTO...
# Fetching data for VRSN...
# Fetching data for VRSK...
# Fetching data for VZ...
# Fetching data for VRTX...
# Fetching data for VTRS...
# Fetching data for VICI...
# Fetching data for V...
# Fetching data for VST...
# Fetching data for VMC...
# Fetching data for WRB...
# Fetching data for GWW...
# Fetching data for WAB...
# Fetching data for WBA...
# Fetching data for WMT...
# Fetching data for DIS...
# Fetching data for WBD...
# Fetching data for WM...
# Fetching data for WAT...
# Fetching data for WEC...
# Fetching data for WFC...
# Fetching data for WELL...
# Fetching data for WST...
# Fetching data for WDC...
# Fetching data for WY...
# Fetching data for WSM...
# Fetching data for WMB...
# Fetching data for WTW...
# Fetching data for WDAY...
# Fetching data for WYNN...
# Fetching data for XEL...
# Fetching data for XYL...
# Fetching data for YUM...
# Fetching data for ZBRA...
# Fetching data for ZBH...
# Fetching data for ZTS...

# %%
insert_stock_info = """
INSERT OR IGNORE INTO companies (ticker, name, sector, industry, market_cap, description)
VALUES (?, ?, ?, ?, ?, ?)"""
cursor.executemany(insert_stock_info, sp_comp_data)

# %% [markdown]
# ## Matching companies sectors and industries to according tables

# %%
cursor.execute("SELECT * FROM industries WHERE sector_id = 8")
sectors = cursor.fetchall()
industries_df = pd.DataFrame(sectors, columns=['industry_id', 'sector_id', 'industry'])
industries_df
# Out:
#    industry_id  sector_id                                industry
# 0            8        801  Consumer Staples Distribution & Retail
# 1            8        802                               Beverages
# 2            8        803                           Food Products
# 3            8        804                                 Tobacco
# 4            8        805                      Household Products
# 5            8        806                  Personal Care Products

# %%
# update_statement = """
#     UPDATE companies
#     SET sector = CASE sector
#         WHEN 'Energy' THEN 1
#         WHEN 'Basic Materials' THEN 2
#         WHEN 'Industrials' THEN 3
#         WHEN 'Utilities' THEN 4
#         WHEN 'Healthcare' THEN 5
#         WHEN 'Financial Services' THEN 6
#         WHEN 'Consumer Cyclical' THEN 7
#         WHEN 'Consumer Defensive' THEN 8
#         WHEN 'Technology' THEN 9
#         WHEN 'Communication Services' THEN 10
#         WHEN 'Real Estate' THEN 11
#         ELSE sector
#     END
# """
update_statement = """ 
    UPDATE companies
    SET sector = (SELECT sector_id FROM sectors WHERE sectors.sector = companies.sector)
    WHERE EXISTS (
    SELECT 1
    FROM sectors
    WHERE sectors.sector = companies.sector
)
"""
cursor.execute(update_statement)

# %%
update_statement = """ 
    UPDATE companies
    SET industry = (SELECT sub_industry_id FROM sub_industries WHERE sub_industries.sub_industry = companies.industry)
    WHERE EXISTS (
    SELECT 1
    FROM sub_industries
    WHERE sub_industries.sub_industry = companies.industry
)
"""
cursor.execute(update_statement)

# %%
test_query = """
SELECT * FROM companies
ORDER BY market_cap DESC
"""
cursor.execute(test_query)
top_companies = cursor.fetchall()
top_companies_df = pd.DataFrame(top_companies, columns=['ticker', 'name', 'sector', 'industry', 'market_cap', 'description'])
top_companies_df['sector'].unique()
# Out:
# array([ 9, 10,  7,  6,  8,  5,  1,  3,  2,  4, 11], dtype=int64)

# %%
top_companies_df
# Out:
#     ticker                         name  sector  industry    market_cap  \
# 0     NVDA           NVIDIA Corporation       9     90602  4.389768e+12
# 1     MSFT        Microsoft Corporation       9     90202  3.981503e+12
# 2     AAPL                   Apple Inc.       9     90401  3.017795e+12
# 3    GOOGL                Alphabet Inc.      10    100501  2.362676e+12
# 4     GOOG                Alphabet Inc.      10    100501  2.362663e+12
# ..     ...                          ...     ...       ...           ...
# 498    MHK      Mohawk Industries, Inc.       7     70302  7.411715e+09
# 499    EMN     Eastman Chemical Company       2     20105  6.979489e+09
# 500    APA              APA Corporation       1     10202  6.592638e+09
# 501    CZR  Caesars Entertainment, Inc.       7     70601  5.274677e+09
# 502   ENPH         Enphase Energy, Inc.       9     90601  4.143499e+09
#
#                                            description
# 0    NVIDIA Corporation, a computing infrastructure...
# 1    Microsoft Corporation develops and supports so...
# 2    Apple Inc. designs, manufactures, and markets ...
# 3    Alphabet Inc. offers various products and plat...
# 4    Alphabet Inc. offers various products and plat...
# ..                                                 ...
# 498  Mohawk Industries, Inc. designs, manufactures,...
# 499  Eastman Chemical Company operates as a special...
# 500  APA Corporation, an independent energy company...
# 501  Caesars Entertainment, Inc. operates as a gami...
# 502  Enphase Energy, Inc., together with its subsid...
#
# [503 rows x 6 columns]

# %% [markdown]
# # Stock prices

# %%
# Populate the stock_prices table
sp_comp_price_df = pd.DataFrame(columns=['Date','Close','High','Low','Open','Volume','Ticker'])
count = 0
undownloaded_tickers = []
for ticker in sp_comp_tickers:
    print(f"Downloading price data for {ticker}...")
    ticker = ticker.replace('.', '-')  # Replace '.' with '-' for yfinance compatibility
    dat = yf.download(ticker, period='max', interval='1d', auto_adjust=True,progress=False,timeout=None, multi_level_index=False)
    if dat.empty:
        print(f"No data found for {ticker}. Will retry later...")
        undownloaded_tickers.append(ticker)
    price_df = pd.DataFrame(dat)
    if('Adj Close' in price_df.columns):
        price_df.drop(['Adj Close'], axis=1, inplace=True)
    price_df['Ticker']  = ticker
    price_df.reset_index(inplace=True)
    sp_comp_price_df = pd.concat([sp_comp_price_df, price_df], axis=0)
    count += 1
    print(f"Downloaded {count}/503 tickers.")
    sleep(0.5)

for ticker in undownloaded_tickers:
    print(f"Retrying download for {ticker}...")
    ticker = ticker.replace('.', '-')  # Replace '.' with '-' for yfinance compatibility
    dat = yf.download(ticker, period='max', interval='1d', auto_adjust=True,progress=False,timeout=None, multi_level_index=False)
    if dat.empty:
        print(f"No data found for {ticker}. Skipping.")
        continue
    price_df = pd.DataFrame(dat)
    if('Adj Close' in price_df.columns):
        price_df.drop(['Adj Close'], axis=1, inplace=True)
    price_df['Ticker']  = ticker
    price_df.reset_index(inplace=True)
    sp_comp_price_df = pd.concat([sp_comp_price_df, price_df], axis=0)
    count += 1
    print(f"Downloaded {ticker}.")
# Out:
# Downloading price data for MMM...
# Downloaded 1/503 tickers.
# Downloading price data for AOS...
# Downloaded 2/503 tickers.
# Downloading price data for ABT...
# Downloaded 3/503 tickers.
# Downloading price data for ABBV...
# Downloaded 4/503 tickers.
# Downloading price data for ACN...
# Downloaded 5/503 tickers.
# Downloading price data for ADBE...
# Downloaded 6/503 tickers.
# Downloading price data for AMD...
# Downloaded 7/503 tickers.
# Downloading price data for AES...
# Downloaded 8/503 tickers.
# Downloading price data for AFL...
# Downloaded 9/503 tickers.
# Downloading price data for A...
# Downloaded 10/503 tickers.
# Downloading price data for APD...
# Downloaded 11/503 tickers.
# Downloading price data for ABNB...
# Downloaded 12/503 tickers.
# Downloading price data for AKAM...
# Downloaded 13/503 tickers.
# Downloading price data for ALB...
# Downloaded 14/503 tickers.
# Downloading price data for ARE...
# Downloaded 15/503 tickers.
# Downloading price data for ALGN...
# Downloaded 16/503 tickers.
# Downloading price data for ALLE...
# Downloaded 17/503 tickers.
# Downloading price data for LNT...
# Downloaded 18/503 tickers.
# Downloading price data for ALL...
# Downloaded 19/503 tickers.
# Downloading price data for GOOGL...
# Downloaded 20/503 tickers.
# Downloading price data for GOOG...
# Downloaded 21/503 tickers.
# Downloading price data for MO...
# Downloaded 22/503 tickers.
# Downloading price data for AMZN...
# Downloaded 23/503 tickers.
# Downloading price data for AMCR...
# Downloaded 24/503 tickers.
# Downloading price data for AEE...
# Downloaded 25/503 tickers.
# Downloading price data for AEP...
# Downloaded 26/503 tickers.
# Downloading price data for AXP...
# Downloaded 27/503 tickers.
# Downloading price data for AIG...
# Downloaded 28/503 tickers.
# Downloading price data for AMT...
# Downloaded 29/503 tickers.
# Downloading price data for AWK...
# Downloaded 30/503 tickers.
# Downloading price data for AMP...
# Downloaded 31/503 tickers.
# Downloading price data for AME...
# Downloaded 32/503 tickers.
# Downloading price data for AMGN...
# Downloaded 33/503 tickers.
# Downloading price data for APH...
# Downloaded 34/503 tickers.
# Downloading price data for ADI...
# Downloaded 35/503 tickers.
# Downloading price data for AON...
# Downloaded 36/503 tickers.
# Downloading price data for APA...
# Downloaded 37/503 tickers.
# Downloading price data for APO...
# Downloaded 38/503 tickers.
# Downloading price data for AAPL...
# Downloaded 39/503 tickers.
# Downloading price data for AMAT...
# Downloaded 40/503 tickers.
# Downloading price data for APTV...
# Downloaded 41/503 tickers.
# Downloading price data for ACGL...
# Downloaded 42/503 tickers.
# Downloading price data for ADM...
# Downloaded 43/503 tickers.
# Downloading price data for ANET...
# Downloaded 44/503 tickers.
# Downloading price data for AJG...
# Downloaded 45/503 tickers.
# Downloading price data for AIZ...
# Downloaded 46/503 tickers.
# Downloading price data for T...
# Downloaded 47/503 tickers.
# Downloading price data for ATO...
# Downloaded 48/503 tickers.
# Downloading price data for ADSK...
# Downloaded 49/503 tickers.
# Downloading price data for ADP...
# Downloaded 50/503 tickers.
# Downloading price data for AZO...
# Downloaded 51/503 tickers.
# Downloading price data for AVB...
# Downloaded 52/503 tickers.
# Downloading price data for AVY...
# Downloaded 53/503 tickers.
# Downloading price data for AXON...
# Downloaded 54/503 tickers.
# Downloading price data for BKR...
# Downloaded 55/503 tickers.
# Downloading price data for BALL...
# Downloaded 56/503 tickers.
# Downloading price data for BAC...
# Downloaded 57/503 tickers.
# Downloading price data for BAX...
# Downloaded 58/503 tickers.
# Downloading price data for BDX...
# Downloaded 59/503 tickers.
# Downloading price data for BRK.B...
# Downloaded 60/503 tickers.
# Downloading price data for BBY...
# Downloaded 61/503 tickers.
# Downloading price data for TECH...
# Downloaded 62/503 tickers.
# Downloading price data for BIIB...
# Downloaded 63/503 tickers.
# Downloading price data for BLK...
# Downloaded 64/503 tickers.
# Downloading price data for BX...
# Downloaded 65/503 tickers.
# Downloading price data for XYZ...
# Downloaded 66/503 tickers.
# Downloading price data for BK...
# Downloaded 67/503 tickers.
# Downloading price data for BA...
# Downloaded 68/503 tickers.
# Downloading price data for BKNG...
# Downloaded 69/503 tickers.
# Downloading price data for BSX...
# Downloaded 70/503 tickers.
# Downloading price data for BMY...
# Downloaded 71/503 tickers.
# Downloading price data for AVGO...
# Downloaded 72/503 tickers.
# Downloading price data for BR...
# Downloaded 73/503 tickers.
# Downloading price data for BRO...
# Downloaded 74/503 tickers.
# Downloading price data for BF.B...
# Downloaded 75/503 tickers.
# Downloading price data for BLDR...
# Downloaded 76/503 tickers.
# Downloading price data for BG...
# Downloaded 77/503 tickers.
# Downloading price data for BXP...
# Downloaded 78/503 tickers.
# Downloading price data for CHRW...
# Downloaded 79/503 tickers.
# Downloading price data for CDNS...
# Downloaded 80/503 tickers.
# Downloading price data for CZR...
# Downloaded 81/503 tickers.
# Downloading price data for CPT...
# Downloaded 82/503 tickers.
# Downloading price data for CPB...
# Downloaded 83/503 tickers.
# Downloading price data for COF...
# Downloaded 84/503 tickers.
# Downloading price data for CAH...
# Downloaded 85/503 tickers.
# Downloading price data for KMX...
# Downloaded 86/503 tickers.
# Downloading price data for CCL...
# Downloaded 87/503 tickers.
# Downloading price data for CARR...
# Downloaded 88/503 tickers.
# Downloading price data for CAT...
# Downloaded 89/503 tickers.
# Downloading price data for CBOE...
# Downloaded 90/503 tickers.
# Downloading price data for CBRE...
# Downloaded 91/503 tickers.
# Downloading price data for CDW...
# Downloaded 92/503 tickers.
# Downloading price data for COR...
# Downloaded 93/503 tickers.
# Downloading price data for CNC...
# Downloaded 94/503 tickers.
# Downloading price data for CNP...
# Downloaded 95/503 tickers.
# Downloading price data for CF...
# Downloaded 96/503 tickers.
# Downloading price data for CRL...
# Downloaded 97/503 tickers.
# Downloading price data for SCHW...
# Downloaded 98/503 tickers.
# Downloading price data for CHTR...
# Downloaded 99/503 tickers.
# Downloading price data for CVX...
# Downloaded 100/503 tickers.
# Downloading price data for CMG...
# Downloaded 101/503 tickers.
# Downloading price data for CB...
# Downloaded 102/503 tickers.
# Downloading price data for CHD...
# Downloaded 103/503 tickers.
# Downloading price data for CI...
# Downloaded 104/503 tickers.
# Downloading price data for CINF...
# Downloaded 105/503 tickers.
# Downloading price data for CTAS...
# Downloaded 106/503 tickers.
# Downloading price data for CSCO...
# Downloaded 107/503 tickers.
# Downloading price data for C...
# Downloaded 108/503 tickers.
# Downloading price data for CFG...
# Downloaded 109/503 tickers.
# Downloading price data for CLX...
# Downloaded 110/503 tickers.
# Downloading price data for CME...
# Downloaded 111/503 tickers.
# Downloading price data for CMS...
# Downloaded 112/503 tickers.
# Downloading price data for KO...
# Downloaded 113/503 tickers.
# Downloading price data for CTSH...
# Downloaded 114/503 tickers.
# Downloading price data for COIN...
# Downloaded 115/503 tickers.
# Downloading price data for CL...
# Downloaded 116/503 tickers.
# Downloading price data for CMCSA...
# Downloaded 117/503 tickers.
# Downloading price data for CAG...
# Downloaded 118/503 tickers.
# Downloading price data for COP...
# Downloaded 119/503 tickers.
# Downloading price data for ED...
# Downloaded 120/503 tickers.
# Downloading price data for STZ...
# Downloaded 121/503 tickers.
# Downloading price data for CEG...
# Downloaded 122/503 tickers.
# Downloading price data for COO...
# Downloaded 123/503 tickers.
# Downloading price data for CPRT...
# Downloaded 124/503 tickers.
# Downloading price data for GLW...
# Downloaded 125/503 tickers.
# Downloading price data for CPAY...
# Downloaded 126/503 tickers.
# Downloading price data for CTVA...
# Downloaded 127/503 tickers.
# Downloading price data for CSGP...
# Downloaded 128/503 tickers.
# Downloading price data for COST...
# Downloaded 129/503 tickers.
# Downloading price data for CTRA...
# Downloaded 130/503 tickers.
# Downloading price data for CRWD...
# Downloaded 131/503 tickers.
# Downloading price data for CCI...
# Downloaded 132/503 tickers.
# Downloading price data for CSX...
# Downloaded 133/503 tickers.
# Downloading price data for CMI...
# Downloaded 134/503 tickers.
# Downloading price data for CVS...
# Downloaded 135/503 tickers.
# Downloading price data for DHR...
# Downloaded 136/503 tickers.
# Downloading price data for DRI...
# Downloaded 137/503 tickers.
# Downloading price data for DDOG...
# Downloaded 138/503 tickers.
# Downloading price data for DVA...
# Downloaded 139/503 tickers.
# Downloading price data for DAY...
# Downloaded 140/503 tickers.
# Downloading price data for DECK...
# Downloaded 141/503 tickers.
# Downloading price data for DE...
# Downloaded 142/503 tickers.
# Downloading price data for DELL...
# Downloaded 143/503 tickers.
# Downloading price data for DAL...
# Downloaded 144/503 tickers.
# Downloading price data for DVN...
# Downloaded 145/503 tickers.
# Downloading price data for DXCM...
# Downloaded 146/503 tickers.
# Downloading price data for FANG...
# Downloaded 147/503 tickers.
# Downloading price data for DLR...
# Downloaded 148/503 tickers.
# Downloading price data for DG...
# Downloaded 149/503 tickers.
# Downloading price data for DLTR...
# Downloaded 150/503 tickers.
# Downloading price data for D...
# Downloaded 151/503 tickers.
# Downloading price data for DPZ...
# Downloaded 152/503 tickers.
# Downloading price data for DASH...
# Downloaded 153/503 tickers.
# Downloading price data for DOV...
# Downloaded 154/503 tickers.
# Downloading price data for DOW...
# Downloaded 155/503 tickers.
# Downloading price data for DHI...
# Downloaded 156/503 tickers.
# Downloading price data for DTE...
# Downloaded 157/503 tickers.
# Downloading price data for DUK...
# Downloaded 158/503 tickers.
# Downloading price data for DD...
# Downloaded 159/503 tickers.
# Downloading price data for EMN...
# Downloaded 160/503 tickers.
# Downloading price data for ETN...
# Downloaded 161/503 tickers.
# Downloading price data for EBAY...
# Downloaded 162/503 tickers.
# Downloading price data for ECL...
# Downloaded 163/503 tickers.
# Downloading price data for EIX...
# Downloaded 164/503 tickers.
# Downloading price data for EW...
# Downloaded 165/503 tickers.
# Downloading price data for EA...
# Downloaded 166/503 tickers.
# Downloading price data for ELV...
# Downloaded 167/503 tickers.
# Downloading price data for EMR...
# Downloaded 168/503 tickers.
# Downloading price data for ENPH...
# Downloaded 169/503 tickers.
# Downloading price data for ETR...
# Downloaded 170/503 tickers.
# Downloading price data for EOG...
# Downloaded 171/503 tickers.
# Downloading price data for EPAM...
# Downloaded 172/503 tickers.
# Downloading price data for EQT...
# Downloaded 173/503 tickers.
# Downloading price data for EFX...
# Downloaded 174/503 tickers.
# Downloading price data for EQIX...
# Downloaded 175/503 tickers.
# Downloading price data for EQR...
# Downloaded 176/503 tickers.
# Downloading price data for ERIE...
# Downloaded 177/503 tickers.
# Downloading price data for ESS...
# Downloaded 178/503 tickers.
# Downloading price data for EL...
# Downloaded 179/503 tickers.
# Downloading price data for EG...
# Downloaded 180/503 tickers.
# Downloading price data for EVRG...
# Downloaded 181/503 tickers.
# Downloading price data for ES...
# Downloaded 182/503 tickers.
# Downloading price data for EXC...
# Downloaded 183/503 tickers.
# Downloading price data for EXE...
# Downloaded 184/503 tickers.
# Downloading price data for EXPE...
# Downloaded 185/503 tickers.
# Downloading price data for EXPD...
# Downloaded 186/503 tickers.
# Downloading price data for EXR...
# Downloaded 187/503 tickers.
# Downloading price data for XOM...
# Downloaded 188/503 tickers.
# Downloading price data for FFIV...
# Downloaded 189/503 tickers.
# Downloading price data for FDS...
# Downloaded 190/503 tickers.
# Downloading price data for FICO...
# Downloaded 191/503 tickers.
# Downloading price data for FAST...
# Downloaded 192/503 tickers.
# Downloading price data for FRT...
# Downloaded 193/503 tickers.
# Downloading price data for FDX...
# Downloaded 194/503 tickers.
# Downloading price data for FIS...
# Downloaded 195/503 tickers.
# Downloading price data for FITB...
# Downloaded 196/503 tickers.
# Downloading price data for FSLR...
# Downloaded 197/503 tickers.
# Downloading price data for FE...
# Downloaded 198/503 tickers.
# Downloading price data for FI...
# Downloaded 199/503 tickers.
# Downloading price data for F...
# Downloaded 200/503 tickers.
# Downloading price data for FTNT...
# Downloaded 201/503 tickers.
# Downloading price data for FTV...
# Downloaded 202/503 tickers.
# Downloading price data for FOXA...
# Downloaded 203/503 tickers.
# Downloading price data for FOX...
# Downloaded 204/503 tickers.
# Downloading price data for BEN...
# Downloaded 205/503 tickers.
# Downloading price data for FCX...
# Downloaded 206/503 tickers.
# Downloading price data for GRMN...
# Downloaded 207/503 tickers.
# Downloading price data for IT...
# Downloaded 208/503 tickers.
# Downloading price data for GE...
# Downloaded 209/503 tickers.
# Downloading price data for GEHC...
# Downloaded 210/503 tickers.
# Downloading price data for GEV...
# Downloaded 211/503 tickers.
# Downloading price data for GEN...
# Downloaded 212/503 tickers.
# Downloading price data for GNRC...
# Downloaded 213/503 tickers.
# Downloading price data for GD...
# Downloaded 214/503 tickers.
# Downloading price data for GIS...
# Downloaded 215/503 tickers.
# Downloading price data for GM...
# Downloaded 216/503 tickers.
# Downloading price data for GPC...
# Downloaded 217/503 tickers.
# Downloading price data for GILD...
# Downloaded 218/503 tickers.
# Downloading price data for GPN...
# Downloaded 219/503 tickers.
# Downloading price data for GL...
# Downloaded 220/503 tickers.
# Downloading price data for GDDY...
# Downloaded 221/503 tickers.
# Downloading price data for GS...
# Downloaded 222/503 tickers.
# Downloading price data for HAL...
# Downloaded 223/503 tickers.
# Downloading price data for HIG...
# Downloaded 224/503 tickers.
# Downloading price data for HAS...
# Downloaded 225/503 tickers.
# Downloading price data for HCA...
# Downloaded 226/503 tickers.
# Downloading price data for DOC...
# Downloaded 227/503 tickers.
# Downloading price data for HSIC...
# Downloaded 228/503 tickers.
# Downloading price data for HSY...
# Downloaded 229/503 tickers.
# Downloading price data for HPE...
# Downloaded 230/503 tickers.
# Downloading price data for HLT...
# Downloaded 231/503 tickers.
# Downloading price data for HOLX...
# Downloaded 232/503 tickers.
# Downloading price data for HD...
# Downloaded 233/503 tickers.
# Downloading price data for HON...
# Downloaded 234/503 tickers.
# Downloading price data for HRL...
# Downloaded 235/503 tickers.
# Downloading price data for HST...
# Downloaded 236/503 tickers.
# Downloading price data for HWM...
# Downloaded 237/503 tickers.
# Downloading price data for HPQ...
# Downloaded 238/503 tickers.
# Downloading price data for HUBB...
# Downloaded 239/503 tickers.
# Downloading price data for HUM...
# Downloaded 240/503 tickers.
# Downloading price data for HBAN...
# Downloaded 241/503 tickers.
# Downloading price data for HII...
# Downloaded 242/503 tickers.
# Downloading price data for IBM...
# Downloaded 243/503 tickers.
# Downloading price data for IEX...
# Downloaded 244/503 tickers.
# Downloading price data for IDXX...
# Downloaded 245/503 tickers.
# Downloading price data for ITW...
# Downloaded 246/503 tickers.
# Downloading price data for INCY...
# Downloaded 247/503 tickers.
# Downloading price data for IR...
# Downloaded 248/503 tickers.
# Downloading price data for PODD...
# Downloaded 249/503 tickers.
# Downloading price data for INTC...
# Downloaded 250/503 tickers.
# Downloading price data for ICE...
# Downloaded 251/503 tickers.
# Downloading price data for IFF...
# Downloaded 252/503 tickers.
# Downloading price data for IP...
# Downloaded 253/503 tickers.
# Downloading price data for IPG...
# Downloaded 254/503 tickers.
# Downloading price data for INTU...
# Downloaded 255/503 tickers.
# Downloading price data for ISRG...
# Downloaded 256/503 tickers.
# Downloading price data for IVZ...
# Downloaded 257/503 tickers.
# Downloading price data for INVH...
# Downloaded 258/503 tickers.
# Downloading price data for IQV...
# Downloaded 259/503 tickers.
# Downloading price data for IRM...
# Downloaded 260/503 tickers.
# Downloading price data for JBHT...
# Downloaded 261/503 tickers.
# Downloading price data for JBL...
# Downloaded 262/503 tickers.
# Downloading price data for JKHY...
# Downloaded 263/503 tickers.
# Downloading price data for J...
# Downloaded 264/503 tickers.
# Downloading price data for JNJ...
# Downloaded 265/503 tickers.
# Downloading price data for JCI...
# Downloaded 266/503 tickers.
# Downloading price data for JPM...
# Downloaded 267/503 tickers.
# Downloading price data for K...
# Downloaded 268/503 tickers.
# Downloading price data for KVUE...
# Downloaded 269/503 tickers.
# Downloading price data for KDP...
# Downloaded 270/503 tickers.
# Downloading price data for KEY...
# Downloaded 271/503 tickers.
# Downloading price data for KEYS...
# Downloaded 272/503 tickers.
# Downloading price data for KMB...
# Downloaded 273/503 tickers.
# Downloading price data for KIM...
# Downloaded 274/503 tickers.
# Downloading price data for KMI...
# Downloaded 275/503 tickers.
# Downloading price data for KKR...
# Downloaded 276/503 tickers.
# Downloading price data for KLAC...
# Downloaded 277/503 tickers.
# Downloading price data for KHC...
# Downloaded 278/503 tickers.
# Downloading price data for KR...
# Downloaded 279/503 tickers.
# Downloading price data for LHX...
# Downloaded 280/503 tickers.
# Downloading price data for LH...
# Downloaded 281/503 tickers.
# Downloading price data for LRCX...
# Downloaded 282/503 tickers.
# Downloading price data for LW...
# Downloaded 283/503 tickers.
# Downloading price data for LVS...
# Downloaded 284/503 tickers.
# Downloading price data for LDOS...
# Downloaded 285/503 tickers.
# Downloading price data for LEN...
# Downloaded 286/503 tickers.
# Downloading price data for LII...
# Downloaded 287/503 tickers.
# Downloading price data for LLY...
# Downloaded 288/503 tickers.
# Downloading price data for LIN...
# Downloaded 289/503 tickers.
# Downloading price data for LYV...
# Downloaded 290/503 tickers.
# Downloading price data for LKQ...
# Downloaded 291/503 tickers.
# Downloading price data for LMT...
# Downloaded 292/503 tickers.
# Downloading price data for L...
# Downloaded 293/503 tickers.
# Downloading price data for LOW...
# Downloaded 294/503 tickers.
# Downloading price data for LULU...
# Downloaded 295/503 tickers.
# Downloading price data for LYB...
# Downloaded 296/503 tickers.
# Downloading price data for MTB...
# Downloaded 297/503 tickers.
# Downloading price data for MPC...
# Downloaded 298/503 tickers.
# Downloading price data for MKTX...
# Downloaded 299/503 tickers.
# Downloading price data for MAR...
# Downloaded 300/503 tickers.
# Downloading price data for MMC...
# Downloaded 301/503 tickers.
# Downloading price data for MLM...
# Downloaded 302/503 tickers.
# Downloading price data for MAS...
# Downloaded 303/503 tickers.
# Downloading price data for MA...
# Downloaded 304/503 tickers.
# Downloading price data for MTCH...
# Downloaded 305/503 tickers.
# Downloading price data for MKC...
# Downloaded 306/503 tickers.
# Downloading price data for MCD...
# Downloaded 307/503 tickers.
# Downloading price data for MCK...
# Downloaded 308/503 tickers.
# Downloading price data for MDT...
# Downloaded 309/503 tickers.
# Downloading price data for MRK...
# Downloaded 310/503 tickers.
# Downloading price data for META...
# Downloaded 311/503 tickers.
# Downloading price data for MET...
# Downloaded 312/503 tickers.
# Downloading price data for MTD...
# Downloaded 313/503 tickers.
# Downloading price data for MGM...
# Downloaded 314/503 tickers.
# Downloading price data for MCHP...
# Downloaded 315/503 tickers.
# Downloading price data for MU...
# Downloaded 316/503 tickers.
# Downloading price data for MSFT...
# Downloaded 317/503 tickers.
# Downloading price data for MAA...
# Downloaded 318/503 tickers.
# Downloading price data for MRNA...
# Downloaded 319/503 tickers.
# Downloading price data for MHK...
# Downloaded 320/503 tickers.
# Downloading price data for MOH...
# Downloaded 321/503 tickers.
# Downloading price data for TAP...
# Downloaded 322/503 tickers.
# Downloading price data for MDLZ...
# Downloaded 323/503 tickers.
# Downloading price data for MPWR...
# Downloaded 324/503 tickers.
# Downloading price data for MNST...
# Downloaded 325/503 tickers.
# Downloading price data for MCO...
# Downloaded 326/503 tickers.
# Downloading price data for MS...
# Downloaded 327/503 tickers.
# Downloading price data for MOS...
# Downloaded 328/503 tickers.
# Downloading price data for MSI...
# Downloaded 329/503 tickers.
# Downloading price data for MSCI...
# Downloaded 330/503 tickers.
# Downloading price data for NDAQ...
# Downloaded 331/503 tickers.
# Downloading price data for NTAP...
# Downloaded 332/503 tickers.
# Downloading price data for NFLX...
# Downloaded 333/503 tickers.
# Downloading price data for NEM...
# Downloaded 334/503 tickers.
# Downloading price data for NWSA...
# Downloaded 335/503 tickers.
# Downloading price data for NWS...
# Downloaded 336/503 tickers.
# Downloading price data for NEE...
# Downloaded 337/503 tickers.
# Downloading price data for NKE...
# Downloaded 338/503 tickers.
# Downloading price data for NI...
# Downloaded 339/503 tickers.
# Downloading price data for NDSN...
# Downloaded 340/503 tickers.
# Downloading price data for NSC...
# Downloaded 341/503 tickers.
# Downloading price data for NTRS...
# Downloaded 342/503 tickers.
# Downloading price data for NOC...
# Downloaded 343/503 tickers.
# Downloading price data for NCLH...
# Downloaded 344/503 tickers.
# Downloading price data for NRG...
# Downloaded 345/503 tickers.
# Downloading price data for NUE...
# Downloaded 346/503 tickers.
# Downloading price data for NVDA...
# Downloaded 347/503 tickers.
# Downloading price data for NVR...
# Downloaded 348/503 tickers.
# Downloading price data for NXPI...
# Downloaded 349/503 tickers.
# Downloading price data for ORLY...
# Downloaded 350/503 tickers.
# Downloading price data for OXY...
# Downloaded 351/503 tickers.
# Downloading price data for ODFL...
# Downloaded 352/503 tickers.
# Downloading price data for OMC...
# Downloaded 353/503 tickers.
# Downloading price data for ON...
# Downloaded 354/503 tickers.
# Downloading price data for OKE...
# Downloaded 355/503 tickers.
# Downloading price data for ORCL...
# Downloaded 356/503 tickers.
# Downloading price data for OTIS...
# Downloaded 357/503 tickers.
# Downloading price data for PCAR...
# Downloaded 358/503 tickers.
# Downloading price data for PKG...
# Downloaded 359/503 tickers.
# Downloading price data for PLTR...
# Downloaded 360/503 tickers.
# Downloading price data for PANW...
# Downloaded 361/503 tickers.
# Downloading price data for PSKY...
# Downloaded 362/503 tickers.
# Downloading price data for PH...
# Downloaded 363/503 tickers.
# Downloading price data for PAYX...
# Downloaded 364/503 tickers.
# Downloading price data for PAYC...
# Downloaded 365/503 tickers.
# Downloading price data for PYPL...
# Downloaded 366/503 tickers.
# Downloading price data for PNR...
# Downloaded 367/503 tickers.
# Downloading price data for PEP...
# Downloaded 368/503 tickers.
# Downloading price data for PFE...
# Downloaded 369/503 tickers.
# Downloading price data for PCG...
# Downloaded 370/503 tickers.
# Downloading price data for PM...
# Downloaded 371/503 tickers.
# Downloading price data for PSX...
# Downloaded 372/503 tickers.
# Downloading price data for PNW...
# Downloaded 373/503 tickers.
# Downloading price data for PNC...
# Downloaded 374/503 tickers.
# Downloading price data for POOL...
# Downloaded 375/503 tickers.
# Downloading price data for PPG...
# Downloaded 376/503 tickers.
# Downloading price data for PPL...
# Downloaded 377/503 tickers.
# Downloading price data for PFG...
# Downloaded 378/503 tickers.
# Downloading price data for PG...
# Downloaded 379/503 tickers.
# Downloading price data for PGR...
# Downloaded 380/503 tickers.
# Downloading price data for PLD...
# Downloaded 381/503 tickers.
# Downloading price data for PRU...
# Downloaded 382/503 tickers.
# Downloading price data for PEG...
# Downloaded 383/503 tickers.
# Downloading price data for PTC...
# Downloaded 384/503 tickers.
# Downloading price data for PSA...
# Downloaded 385/503 tickers.
# Downloading price data for PHM...
# Downloaded 386/503 tickers.
# Downloading price data for PWR...
# Downloaded 387/503 tickers.
# Downloading price data for QCOM...
# Downloaded 388/503 tickers.
# Downloading price data for DGX...
# Downloaded 389/503 tickers.
# Downloading price data for RL...
# Downloaded 390/503 tickers.
# Downloading price data for RJF...
# Downloaded 391/503 tickers.
# Downloading price data for RTX...
# Downloaded 392/503 tickers.
# Downloading price data for O...
# Downloaded 393/503 tickers.
# Downloading price data for REG...
# Downloaded 394/503 tickers.
# Downloading price data for REGN...
# Downloaded 395/503 tickers.
# Downloading price data for RF...
# Downloaded 396/503 tickers.
# Downloading price data for RSG...
# Downloaded 397/503 tickers.
# Downloading price data for RMD...
# Downloaded 398/503 tickers.
# Downloading price data for RVTY...
# Downloaded 399/503 tickers.
# Downloading price data for ROK...
# Downloaded 400/503 tickers.
# Downloading price data for ROL...
# Downloaded 401/503 tickers.
# Downloading price data for ROP...
# Downloaded 402/503 tickers.
# Downloading price data for ROST...
# Downloaded 403/503 tickers.
# Downloading price data for RCL...
# Downloaded 404/503 tickers.
# Downloading price data for SPGI...
# Downloaded 405/503 tickers.
# Downloading price data for CRM...
# Downloaded 406/503 tickers.
# Downloading price data for SBAC...
# Downloaded 407/503 tickers.
# Downloading price data for SLB...
# Downloaded 408/503 tickers.
# Downloading price data for STX...
# Downloaded 409/503 tickers.
# Downloading price data for SRE...
# Downloaded 410/503 tickers.
# Downloading price data for NOW...
# Downloaded 411/503 tickers.
# Downloading price data for SHW...
# Downloaded 412/503 tickers.
# Downloading price data for SPG...
# Downloaded 413/503 tickers.
# Downloading price data for SWKS...
# Downloaded 414/503 tickers.
# Downloading price data for SJM...
# Downloaded 415/503 tickers.
# Downloading price data for SW...
# Downloaded 416/503 tickers.
# Downloading price data for SNA...
# Downloaded 417/503 tickers.
# Downloading price data for SOLV...
# Downloaded 418/503 tickers.
# Downloading price data for SO...
# Downloaded 419/503 tickers.
# Downloading price data for LUV...
# Downloaded 420/503 tickers.
# Downloading price data for SWK...
# Downloaded 421/503 tickers.
# Downloading price data for SBUX...
# Downloaded 422/503 tickers.
# Downloading price data for STT...
# Downloaded 423/503 tickers.
# Downloading price data for STLD...
# Downloaded 424/503 tickers.
# Downloading price data for STE...
# Downloaded 425/503 tickers.
# Downloading price data for SYK...
# Downloaded 426/503 tickers.
# Downloading price data for SMCI...
# Downloaded 427/503 tickers.
# Downloading price data for SYF...
# Downloaded 428/503 tickers.
# Downloading price data for SNPS...
# Downloaded 429/503 tickers.
# Downloading price data for SYY...
# Downloaded 430/503 tickers.
# Downloading price data for TMUS...
# Downloaded 431/503 tickers.
# Downloading price data for TROW...
# Downloaded 432/503 tickers.
# Downloading price data for TTWO...
# Downloaded 433/503 tickers.
# Downloading price data for TPR...
# Downloaded 434/503 tickers.
# Downloading price data for TRGP...
# Downloaded 435/503 tickers.
# Downloading price data for TGT...
# Downloaded 436/503 tickers.
# Downloading price data for TEL...
# Downloaded 437/503 tickers.
# Downloading price data for TDY...
# Downloaded 438/503 tickers.
# Downloading price data for TER...
# Downloaded 439/503 tickers.
# Downloading price data for TSLA...
# Downloaded 440/503 tickers.
# Downloading price data for TXN...
# Downloaded 441/503 tickers.
# Downloading price data for TPL...
# Downloaded 442/503 tickers.
# Downloading price data for TXT...
# Downloaded 443/503 tickers.
# Downloading price data for TMO...
# Downloaded 444/503 tickers.
# Downloading price data for TJX...
# Downloaded 445/503 tickers.
# Downloading price data for TKO...
# Downloaded 446/503 tickers.
# Downloading price data for TTD...
# Downloaded 447/503 tickers.
# Downloading price data for TSCO...
# Downloaded 448/503 tickers.
# Downloading price data for TT...
# Downloaded 449/503 tickers.
# Downloading price data for TDG...
# Downloaded 450/503 tickers.
# Downloading price data for TRV...
# Downloaded 451/503 tickers.
# Downloading price data for TRMB...
# Downloaded 452/503 tickers.
# Downloading price data for TFC...
# Downloaded 453/503 tickers.
# Downloading price data for TYL...
# Downloaded 454/503 tickers.
# Downloading price data for TSN...
# Downloaded 455/503 tickers.
# Downloading price data for USB...
# Downloaded 456/503 tickers.
# Downloading price data for UBER...
# Downloaded 457/503 tickers.
# Downloading price data for UDR...
# Downloaded 458/503 tickers.
# Downloading price data for ULTA...
# Downloaded 459/503 tickers.
# Downloading price data for UNP...
# Downloaded 460/503 tickers.
# Downloading price data for UAL...
# Downloaded 461/503 tickers.
# Downloading price data for UPS...
# Downloaded 462/503 tickers.
# Downloading price data for URI...
# Downloaded 463/503 tickers.
# Downloading price data for UNH...
# Downloaded 464/503 tickers.
# Downloading price data for UHS...
# Downloaded 465/503 tickers.
# Downloading price data for VLO...
# Downloaded 466/503 tickers.
# Downloading price data for VTR...
# Downloaded 467/503 tickers.
# Downloading price data for VLTO...
# Downloaded 468/503 tickers.
# Downloading price data for VRSN...
# Downloaded 469/503 tickers.
# Downloading price data for VRSK...
# Downloaded 470/503 tickers.
# Downloading price data for VZ...
# Downloaded 471/503 tickers.
# Downloading price data for VRTX...
# Downloaded 472/503 tickers.
# Downloading price data for VTRS...
# Downloaded 473/503 tickers.
# Downloading price data for VICI...
# Downloaded 474/503 tickers.
# Downloading price data for V...
# Downloaded 475/503 tickers.
# Downloading price data for VST...
# Downloaded 476/503 tickers.
# Downloading price data for VMC...
# Downloaded 477/503 tickers.
# Downloading price data for WRB...
# Downloaded 478/503 tickers.
# Downloading price data for GWW...
# Downloaded 479/503 tickers.
# Downloading price data for WAB...
# Downloaded 480/503 tickers.
# Downloading price data for WBA...
# Downloaded 481/503 tickers.
# Downloading price data for WMT...
# Downloaded 482/503 tickers.
# Downloading price data for DIS...
# Downloaded 483/503 tickers.
# Downloading price data for WBD...
# Downloaded 484/503 tickers.
# Downloading price data for WM...
# Downloaded 485/503 tickers.
# Downloading price data for WAT...
# Downloaded 486/503 tickers.
# Downloading price data for WEC...
# Downloaded 487/503 tickers.
# Downloading price data for WFC...
# Downloaded 488/503 tickers.
# Downloading price data for WELL...
# Downloaded 489/503 tickers.
# Downloading price data for WST...
# Downloaded 490/503 tickers.
# Downloading price data for WDC...
# Downloaded 491/503 tickers.
# Downloading price data for WY...
# Downloaded 492/503 tickers.
# Downloading price data for WSM...
# Downloaded 493/503 tickers.
# Downloading price data for WMB...
# Downloaded 494/503 tickers.
# Downloading price data for WTW...
# Downloaded 495/503 tickers.
# Downloading price data for WDAY...
# Downloaded 496/503 tickers.
# Downloading price data for WYNN...
# Downloaded 497/503 tickers.
# Downloading price data for XEL...
# Downloaded 498/503 tickers.
# Downloading price data for XYL...
# Downloaded 499/503 tickers.
# Downloading price data for YUM...
# Downloaded 500/503 tickers.
# Downloading price data for ZBRA...
# Downloaded 501/503 tickers.
# Downloading price data for ZBH...
# Downloaded 502/503 tickers.
# Downloading price data for ZTS...
# Downloaded 503/503 tickers.

# %%
today = date.today().strftime("%Y-%m-%d")

# %%
sp_comp_price_df = sp_comp_price_df[['Ticker', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume']]
sp_comp_price_df['Date'] = pd.to_datetime(sp_comp_price_df["Date"]).dt.strftime("%Y-%m-%d")
sp_comp_price_df = sp_comp_price_df.loc[sp_comp_price_df['Date'] < today]
conn.executemany(
    "INSERT OR IGNORE INTO price (ticker, date, open, high, low, close, volume) VALUES (?, ?, ?, ?, ?, ?, ?)",
    sp_comp_price_df.values.tolist()
)

# %%
cursor.execute("SELECT COUNT(DISTINCT ticker) FROM price")
count = cursor.fetchone()
count[0]
# Out:
# 503

# %%
cursor.execute("SELECT * FROM price WHERE Ticker = 'AAPL' ORDER BY Date DESC")
count = cursor.fetchall()
count_df = pd.DataFrame(count, columns=['Ticker', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume'])

# %%
# Commit changes and close the connection
conn.commit()
conn.close()
